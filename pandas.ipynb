# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('bollywood.csv')
data
# Out:
#          imdbId                                title  releaseYear  \
# 0     tt0118578                               Albela         2001
# 1     tt0169102    Lagaan: Once Upon a Time in India         2001
# 2     tt0187279             Meri Biwi Ka Jawab Nahin         2004
# 3     tt0222024               Hum Tumhare Hain Sanam         2002
# 4     tt0227194                           One 2 Ka 4         2001
# 5     tt0238936                               Devdas         2002
# 6     tt0247911          Aap Mujhe Achche Lagne Lage         2002
# 7     tt0248126          Kabhi Khushi Kabhie Gham...         2001
# 8     tt0248216                  Na Tum Jaano Na Hum         2002
# 9     tt0248617                           Yaadein...         2001
# 10    tt0255713                             Zubeidaa         2001
# 11    tt0256692            Chori Chori Chupke Chupke         2001
# 12    tt0265148             Main Prem Ki Diwani Hoon         2003
# ...

# %%
data.head() #this function shows the top 5 rows of the data
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 0  Honey Irani (screenplay) | Honey Irani (story)...
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
# ...

# %%
data.head(10) #apne hisab se rows change kr sakte ho
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 0  tt0118578                             Albela         2001  20 Apr 2001
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
# 5  tt0238936                             Devdas         2002  12 Jul 2002
# 6  tt0247911        Aap Mujhe Achche Lagne Lage         2002  19 Apr 2002
# 7  tt0248126        Kabhi Khushi Kabhie Gham...         2001  14 Dec 2001
# 8  tt0248216                Na Tum Jaano Na Hum         2002  10 May 2002
# 9  tt0248617                         Yaadein...         2001  27 Jun 2001
#
#                          genre  \
# 0                      Romance
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# ...

# %%
data.tail(2) #shows the last 2 rows
# Out:
#          imdbId            title  releaseYear  releaseDate     genre  \
# 1282  tt4219300  Gollu aur Pappu         2014  21 Nov 2014    Comedy
# 1283  tt4228746              Zid         2014  28 Nov 2014  Thriller
#
#                                writers  \
# 1282                               NaN
# 1283  Vivek Agnihotri | Rohit Malhotra
#
#                                                  actors  \
# 1282  Vir Das | Sandeepa Dhar | Rahul Handa | Dimple...
# 1283  Shradha Das | Mohan Kapoor | Mannara | Karanvi...
#
#                            directors  sequel  hitFlop
# 1282                  Kabir Sadanand     0.0        1
# 1283  Rohit Malhotra | Anubhav Sinha     0.0        2

# %%
data.shape #shows no. of rows and columns
# Out:
# (1284, 10)

# %%
data.columns #shows the head of the columns
# Out:
# Index(['imdbId', 'title', 'releaseYear', 'releaseDate', 'genre', 'writers',
#        'actors', 'directors', 'sequel', 'hitFlop'],
#       dtype='object')

# %%
data.values #it is a 2D numpy array
# Out:
# array([['tt0118578', 'Albela', 2001, ..., 'Deepak Sareen', 0.0, 2],
#        ['tt0169102', 'Lagaan: Once Upon a Time in India', 2001, ...,
#         'Ashutosh Gowariker', 0.0, 6],
#        ['tt0187279', 'Meri Biwi Ka Jawab Nahin', 2004, ...,
#         'Pankaj Parashar | S.M. Iqbal', 0.0, 1],
#        ...,
#        ['tt4190220', 'Zed Plus', 2014, ..., 'Chandra Prakash Dwivedi',
#         0.0, 1],
#        ['tt4219300', 'Gollu aur Pappu', 2014, ..., 'Kabir Sadanand', 0.0,
#         1],
#        ['tt4228746', 'Zid', 2014, ..., 'Rohit Malhotra | Anubhav Sinha',
#         0.0, 2]], dtype=object)

# %%
data.info() #pandas always string ko object bolta hain
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null float64
# hitFlop        1284 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
#from the above info we can see that alot of infos are missing under several columns

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#dataframe is the type of the  entire data

# %%
#how to fetch the required column
data['title']
# Out:
# 0                                    Albela
# 1         Lagaan: Once Upon a Time in India
# 2                  Meri Biwi Ka Jawab Nahin
# 3                    Hum Tumhare Hain Sanam
# 4                                One 2 Ka 4
# 5                                    Devdas
# 6               Aap Mujhe Achche Lagne Lage
# 7               Kabhi Khushi Kabhie Gham...
# 8                       Na Tum Jaano Na Hum
# 9                                Yaadein...
# 10                                 Zubeidaa
# 11                Chori Chori Chupke Chupke
# 12                 Main Prem Ki Diwani Hoon
# 13                                  Officer
# 14                              Chandni Bar
# 15                  Kuch Khatti Kuch Meethi
# 16                                   Censor
# 17                                     Farz
# 18               Mujhe Meri Biwi Se Bachaao
# 19                     Mujhse Dosti Karoge!
# 20      Daman: A Victim of Marital Violence
# ...

# %%
type(data['title'])
# Out:
# pandas.core.series.Series

# %%
#we can see its a series type of data. that is each column is series data type. whereas the entore data is a dataframe

# %%
data['title'][0]
# Out:
# 'Albela'

# %%
data['hitFlop']
# Out:
# 0       2
# 1       6
# 2       1
# 3       4
# 4       1
# 5       6
# 6       2
# 7       8
# 8       1
# 9       2
# 10      1
# 11      5
# 12      2
# 13      2
# 14      5
# 15      2
# 16      1
# 17      4
# 18      1
# 19      2
# 20      1
# 21      3
# 22      1
# 23      1
# 24      1
# 25      1
# 26      4
# 27      6
# 28      3
# 29      1
#        ..
# 1254    1
# 1255    4
# 1256    2
# 1257    1
# 1258    1
# 1259    2
# 1260    1
# 1261    6
# 1262    1
# 1263    2
# 1264    2
# 1265    1
# 1266    1
# 1267    1
# 1268    1
# 1269    1
# 1270    1
# 1271    1
# 1272    2
# 1273    1
# 1274    1
# 1275    1
# 1276    1
# 1277    1
# 1278    1
# 1279    1
# 1280    1
# 1281    1
# 1282    1
# 1283    2
# Name: hitFlop, Length: 1284, dtype: int64

# %%
new_data=data[['title','genre','hitFlop']] #we are taking out our required datas

# %%
new_data.head()
# Out:
#                                title                        genre  hitFlop
# 0                             Albela                      Romance        2
# 1  Lagaan: Once Upon a Time in India  Adventure | Drama | Musical        6
# 2           Meri Biwi Ka Jawab Nahin              Action | Comedy        1
# 3             Hum Tumhare Hain Sanam              Drama | Romance        4
# 4                         One 2 Ka 4      Action | Comedy | Drama        1

# %%
data.iloc[0]  #gives us our required row
# Out:
# imdbId                                                 tt0118578
# title                                                     Albela
# releaseYear                                                 2001
# releaseDate                                          20 Apr 2001
# genre                                                    Romance
# writers        Honey Irani (screenplay) | Honey Irani (story)...
# actors         Govinda | Aishwarya Rai Bachchan | Jackie Shro...
# directors                                          Deepak Sareen
# sequel                                                         0
# hitFlop                                                        2
# Name: 0, dtype: object

# %%
data.iloc[1:5] #iloc is same as numpy wala indexing
# Out:
#       imdbId                              title  releaseYear  releaseDate  \
# 1  tt0169102  Lagaan: Once Upon a Time in India         2001  08 May 2002
# 2  tt0187279           Meri Biwi Ka Jawab Nahin         2004  02 Jul 2004
# 3  tt0222024             Hum Tumhare Hain Sanam         2002  24 May 2002
# 4  tt0227194                         One 2 Ka 4         2001  30 Mar 2001
#
#                          genre  \
# 1  Adventure | Drama | Musical
# 2              Action | Comedy
# 3              Drama | Romance
# 4      Action | Comedy | Drama
#
#                                              writers  \
# 1  Ashutosh Gowariker (story) | Ashutosh Gowarike...
# 2                                                NaN
# 3  K.S. Adiyaman | Arun Kumar (assistant dialogue...
# 4  Sanjay Chhel | Raaj Kumar Dahima (screenplay) ...
#
#                                               actors  \
# 1  Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# ...

# %%
data.iloc[1:4,[2,4,6]] #with this we can get our required rows and columns, even though our rows or columns are non continuous
# Out:
#    releaseYear                        genre  \
# 1         2001  Adventure | Drama | Musical
# 2         2004              Action | Comedy
# 3         2002              Drama | Romance
#
#                                               actors
# 1  Aamir Khan | Gracy Singh | Rachel Shelley | Pa...
# 2  Akshay Kumar | Sridevi | Gulshan Grover | Laxm...
# 3  Shah Rukh Khan | Madhuri Dixit | Salman Khan |...

# %%
data['hitFlop']*2  #scalar multiplication
# Out:
# 0        4
# 1       12
# 2        2
# 3        8
# 4        2
# 5       12
# 6        4
# 7       16
# 8        2
# 9        4
# 10       2
# 11      10
# 12       4
# 13       4
# 14      10
# 15       4
# 16       2
# 17       8
# 18       2
# 19       4
# 20       2
# 21       6
# 22       2
# 23       2
# 24       2
# 25       2
# 26       8
# 27      12
# 28       6
# 29       2
#         ..
# 1254     2
# 1255     8
# 1256     4
# 1257     2
# 1258     2
# 1259     4
# 1260     2
# 1261    12
# 1262     2
# 1263     4
# 1264     4
# 1265     2
# 1266     2
# 1267     2
# 1268     2
# 1269     2
# 1270     2
# 1271     2
# 1272     4
# 1273     2
# 1274     2
# 1275     2
# 1276     2
# 1277     2
# 1278     2
# 1279     2
# 1280     2
# 1281     2
# 1282     2
# 1283     4
# Name: hitFlop, Length: 1284, dtype: int64

# %%
data['title']+" ghatiya hai" #scalar operation can be performed over one column or row
# Out:
# 0                                    Albela ghatiya hai
# 1         Lagaan: Once Upon a Time in India ghatiya hai
# 2                  Meri Biwi Ka Jawab Nahin ghatiya hai
# 3                    Hum Tumhare Hain Sanam ghatiya hai
# 4                                One 2 Ka 4 ghatiya hai
# 5                                    Devdas ghatiya hai
# 6               Aap Mujhe Achche Lagne Lage ghatiya hai
# 7               Kabhi Khushi Kabhie Gham... ghatiya hai
# 8                       Na Tum Jaano Na Hum ghatiya hai
# 9                                Yaadein... ghatiya hai
# 10                                 Zubeidaa ghatiya hai
# 11                Chori Chori Chupke Chupke ghatiya hai
# 12                 Main Prem Ki Diwani Hoon ghatiya hai
# 13                                  Officer ghatiya hai
# 14                              Chandni Bar ghatiya hai
# 15                  Kuch Khatti Kuch Meethi ghatiya hai
# 16                                   Censor ghatiya hai
# ...

# %%
data['hitFlop']>7
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7        True
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1254    False
# 1255    False
# 1256    False
# 1257    False
# 1258    False
# 1259    False
# 1260    False
# 1261    False
# 1262    False
# 1263    False
# 1264    False
# 1265    False
# 1266    False
# 1267    False
# 1268    False
# 1269    False
# 1270    False
# 1271    False
# 1272    False
# 1273    False
# 1274    False
# 1275    False
# 1276    False
# 1277    False
# 1278    False
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# ...

# %%
d=data['hitFlop']>7

# %%
data[d].shape
# Out:
# (24, 10)

# %%
m=data['hitFlop']>5

# %%
n=data['genre'][m]=='Romance'

# %%
o=data['releaseYear']<2010

# %%
data[m & n & o]
# Out:
#         imdbId                  title  releaseYear  releaseDate    genre  \
# 33   tt0284328  Mujhe Kucch Kehna Hai         2001  25 May 2001  Romance
# 150  tt0348258       Tujhe Meri Kasam         2003  03 Jan 2003  Romance
#
#                                            writers  \
# 33   Rumi Jaffery (story) | A. Karunakaran (story)
# 150                         Neeraj Vora (dialogue)
#
#                                                 actors         directors  \
# 33   Tusshar Kapoor | Kareena Kapoor | Amrish Puri ...    Satish Kaushik
# 150  Ritesh Deshmukh | Shakti Kapoor | Supriya Karn...  Vijay K. Bhaskar
#
#      sequel  hitFlop
# 33      0.0        7
# 150     0.0        6

# %%
data['releaseYear'].value_counts() #counts the no. of movies in every year
# Out:
# 2010    116
# 2011    112
# 2014    110
# 2005    106
# 2013    102
# 2012     99
# 2008     98
# 2003     95
# 2009     91
# 2004     88
# 2002     79
# 2007     66
# 2001     62
# 2006     60
# Name: releaseYear, dtype: int64

# %%
data['releaseYear'].value_counts()
# Out:
# 2010    116
# 2011    112
# 2014    110
# 2005    106
# 2013    102
# 2012     99
# 2008     98
# 2003     95
# 2009     91
# 2004     88
# 2002     79
# 2007     66
# 2001     62
# 2006     60
# Name: releaseYear, dtype: int64

# %%
data=pd.read_csv('food.csv')
data
# Out:
#          Name Gender     City Frequency      Item  Spends
# 0      Nitish      M  Kolkata    Weekly    Burger      11
# 1         Anu      F  Gurgaon     Daily  Sandwich      14
# 2       Mukku      M  Kolkata      Once      Vada      25
# 3        Suri      M  Kolkata   Monthly     Pizza      56
# 4       Rajiv      M    Patna     Never    Paneer      34
# 5    Vandanda      F    Patna      Once   Chicken      23
# 6      Piyush      M   Ranchi     Never   Chicken      67
# 7     Radhika      F   Mumbai   Monthly     Pizza      43
# 8       Sunil      M   Mumbai   Monthly      Vada      34
# 9     Madhuri      F     Pune     Daily    Paneer      66
# 10      Sonal      F     Pune   Monthly     Pizza      89
# 11      Abhay      M    Patna     Daily    Burger      65
# 12     Vineet      M   Ranchi      Once  Sandwich      34
# 13      Sumit      M  Gurgaon     Never  Sandwich      34
# 14     Ranbir      M   Mumbai    Weekly      Vada      55
# ...

# %%
data.dropna().shape
# Out:
# (1131, 10)

# %%
data.describe() #applicable only in the numerical column
# Out:
#        releaseYear       sequel      hitFlop
# count  1284.000000  1281.000000  1284.000000
# mean   2007.989097     0.035129     2.144081
# std       4.005243     0.188371     1.812820
# min    2001.000000     0.000000     1.000000
# 25%    2004.000000     0.000000     1.000000
# 50%    2008.000000     0.000000     1.000000
# 75%    2011.000000     0.000000     2.000000
# max    2014.000000     2.000000     9.000000

# %%
data.corr() #it gives the correlation in between all the numerical columns
# Out:
#              releaseYear    sequel   hitFlop
# releaseYear     1.000000  0.132172  0.009878
# sequel          0.132172  1.000000  0.251237
# hitFlop         0.009878  0.251237  1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null float64
# hitFlop        1284 non-null int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 100.4+ KB

# %%
data['sequel'].value_counts()
# Out:
# 0.0    1237
# 1.0      43
# 2.0       1
# Name: sequel, dtype: int64

# %%
data['sequel']=data['sequel'].astype('category') #category is the type we use where there is less data variation.so by using astye category,im optimizing it and lessening the memory space

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1284 entries, 0 to 1283
# Data columns (total 10 columns):
# imdbId         1284 non-null object
# title          1284 non-null object
# releaseYear    1284 non-null int64
# releaseDate    1231 non-null object
# genre          1282 non-null object
# writers        1165 non-null object
# actors         1281 non-null object
# directors      1280 non-null object
# sequel         1281 non-null category
# hitFlop        1284 non-null int64
# dtypes: category(1), int64(2), object(7)
# memory usage: 91.7+ KB

# %%
data.sort_values('title') #ascending order title wise
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 406   tt0473567                           ...Yahaan         2005  29 Jul 2005
# 732   tt1385824         13B: Fear Has a New Address         2009  06 Mar 2009
# 74    tt0313844                         16 December         2002  22 Mar 2002
# 700   tt1301698                                1920         2008  12 Sep 2008
# 1048  tt2222550                  1920: Evil Returns         2012  02 Nov 2012
# 1061  tt2246533             2 Nights in Soul Valley         2012  28 Dec 2012
# 391   tt0463279                           2 October         2003          NaN
# 1114  tt2372678                            2 States         2014  18 Apr 2014
# 89    tt0324951            23rd March 1931: Shaheed         2002  07 Jun 2002
# 642   tt1216276                26th July at Barista         2008  14 Mar 2008
# 1266  tt3720634       3 AM: A Paranormal Experience         2014  26 Sep 2014
# ...

# %%
data.sort_values('title',ascending=False) #descending order mein sorting hua
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 10    tt0255713                            Zubeidaa         2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# 806   tt1605790                            Zokkomon         2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam         2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara         2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai         2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50         2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks         2006  06 Oct 2006
# 445   tt0488906                               Zinda         2006  12 Jan 2006
# 1283  tt4228746                                 Zid         2014  28 Nov 2014
# 364   tt0451983                               Zeher         2005  25 Mar 2005
# ...

# %%
data.sort_values('title',ascending=False,inplace=True) #for making the change permanent

# %%
data
# Out:
#          imdbId                               title  releaseYear  releaseDate  \
# 10    tt0255713                            Zubeidaa         2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!         2009  12 Jun 2009
# 806   tt1605790                            Zokkomon         2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam         2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara         2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai         2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50         2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks         2006  06 Oct 2006
# 445   tt0488906                               Zinda         2006  12 Jan 2006
# 1283  tt4228746                                 Zid         2014  28 Nov 2014
# 364   tt0451983                               Zeher         2005  25 Mar 2005
# ...

# %%
data.sort_values(['releaseYear','title'],ascending=[True,False]) #sorting year wise and within a particular year tittle wise sort
# Out:
#          imdbId                              title  releaseYear  releaseDate  \
# 10    tt0255713                           Zubeidaa         2001  19 Jan 2001
# 607   tt1176141                           Zahreela         2001  05 Mar 2001
# 50    tt0298607               Yeh Zindagi Ka Safar         2001  16 Nov 2001
# 49    tt0298606      Yeh Teraa Ghar Yeh Meraa Ghar         2001  12 Oct 2001
# 42    tt0292740           Yeh Raaste Hain Pyaar Ke         2001  10 Aug 2001
# 595   tt1139671             Yeh Hai Pyar Ka Mausam         2001          NaN
# 9     tt0248617                         Yaadein...         2001  27 Jun 2001
# 57    tt0303187                      Veer Savarkar         2001          NaN
# 36    tt0288273                             Uljhan         2001  04 May 2001
# 38    tt0290326   Tum Bin...: Love Will Find a Way         2001  13 Jul 2001
# 149   tt0348190                          Tere Liye         2001  14 Dec 2001
# ...

# %%
data.rename(columns={'title':'name','releaseYear':'year'},inplace=True) #for renaming the column names.since this function will temporary so we will use inplace function to make it permanent

# %%
data
# Out:
#          imdbId                                name  year  releaseDate  \
# 10    tt0255713                            Zubeidaa  2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# ...

# %%
data.drop(10) #it deletes the row,row no. wise as we specified
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data #but again we see that the function was temporary
# Out:
#          imdbId                                name  year  releaseDate  \
# 10    tt0255713                            Zubeidaa  2001  19 Jan 2001
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# ...

# %%
data.drop(10,inplace=True)

# %%
data
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data.drop('imdbId',axis=1) #deleting columnwise #again we make the change permanent by using inplace function
# Out:
#                                     name  year  releaseDate  \
# 770               Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806                             Zokkomon  2011  22 Apr 2011
# 1015                   Zindagi Tere Naam  2012  16 Mar 2012
# 789             Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128              Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183                       Zindagi 50 50  2013  24 May 2013
# 487                       Zindaggi Rocks  2006  06 Oct 2006
# 445                                Zinda  2006  12 Jan 2006
# 1283                                 Zid  2014  28 Nov 2014
# 364                                Zeher  2005  25 Mar 2005
# 1281                            Zed Plus  2014  28 Nov 2014
# 1105                             Zanjeer  2013  06 Sep 2013
# 219                               Zameen  2003  26 Sep 2003
# 607                             Zahreela  2001  05 Mar 2001
# 582                             Yuvvraaj  2008  21 Nov 2008
# ...

# %%
#how to create a new column?
data['verdict']=""

# %%
data.columns #here we can see the new column added
# Out:
# Index(['imdbId', 'name', 'year', 'releaseDate', 'genre', 'writers', 'actors',
#        'directors', 'sequel', 'hitFlop', 'verdict'],
#       dtype='object')

# %%
def boxOffice(rating):
    if rating>=6:
        return "Hit"
    else:
        return "Flop"

# %%
boxOffice(8)
# Out:
# 'Hit'

# %%
data['verdict']=data['hitFlop'].apply(boxOffice)

# %%
data
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data['writers'].count() #all writers
# Out:
# 1164

# %%
data['writers'].value_counts() #distinct writers
# Out:
# Dilip Shukla                                                                                                                                                                                                                                                          6
# Nagesh Kukunoor                                                                                                                                                                                                                                                       6
# Imtiaz Ali                                                                                                                                                                                                                                                            4
# ...

# %%
data.dropna() #for any row, if any column value is missing then dropna function will remove that entire row
# Out:
#          imdbId                                name  year  releaseDate  \
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# 219   tt0382385                              Zameen  2003  26 Sep 2003
# 607   tt1176141                            Zahreela  2001  05 Mar 2001
# 582   tt1105747                            Yuvvraaj  2008  21 Nov 2008
# ...

# %%
data.dropna(how='all') #this will delete only those rows where all the column values are missing
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data.dropna(subset=['sequel','releaseDate']) #removes the rows where there is no release date and sequel
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data.fillna({'writers':'no writer','sequel':0},inplace=True) #it fills the place where writer name and sequel is not mentioned

# %%
data
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data.drop_duplicates() #it removes the duplicate rows
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
data.drop_duplicates(subset=['directors','year'],keep="last") #it removes the duplicate directors and duplicate year and we will keep only the last wala row
# Out:
#          imdbId                                name  year  releaseDate  \
# 770   tt1479857              Zor Lagaa Ke... Haiya!  2009  12 Jun 2009
# 806   tt1605790                            Zokkomon  2011  22 Apr 2011
# 1015  tt2164702                   Zindagi Tere Naam  2012  16 Mar 2012
# 789   tt1562872            Zindagi Na Milegi Dobara  2011  15 Jul 2011
# 128   tt0340464             Zindagi Khoobsoorat Hai  2002  04 Oct 2002
# 1183  tt2929840                       Zindagi 50 50  2013  24 May 2013
# 487   tt0823261                      Zindaggi Rocks  2006  06 Oct 2006
# 445   tt0488906                               Zinda  2006  12 Jan 2006
# 1283  tt4228746                                 Zid  2014  28 Nov 2014
# 364   tt0451983                               Zeher  2005  25 Mar 2005
# 1281  tt4190220                            Zed Plus  2014  28 Nov 2014
# 1105  tt2357489                             Zanjeer  2013  06 Sep 2013
# ...

# %%
food=pd.read_csv('food.csv')
food.head()
# Out:
#      Name Gender     City Frequency      Item  Spends
# 0  Nitish      M  Kolkata    Weekly    Burger      11
# 1     Anu      F  Gurgaon     Daily  Sandwich      14
# 2   Mukku      M  Kolkata      Once      Vada      25
# 3    Suri      M  Kolkata   Monthly     Pizza      56
# 4   Rajiv      M    Patna     Never    Paneer      34

# %%
food.shape
# Out:
# (50, 6)

# %%
food.pivot_table(index=['Item','Gender'],columns=['City','Frequency'],values='Spends',aggfunc='mean') #creating a pivot table.
# Out:
# City            Chennai                      Gurgaon                      \
# Frequency         Daily Monthly  Once Weekly   Daily Monthly Never  Once
# Item     Gender
# Burger   F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN  44.0    NaN     NaN     NaN   NaN   NaN
# Chicken  F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
# Paneer   F          NaN     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN    67.0   NaN    NaN     NaN     NaN   NaN   NaN
# Pizza    F         34.0     NaN   NaN    NaN     NaN     NaN   NaN   NaN
#          M          NaN     NaN  54.0    NaN     NaN     NaN   NaN   NaN
# Sandwich F          NaN     NaN   NaN   43.0    14.0     NaN   NaN   NaN
#          M          NaN    43.0   NaN    NaN     NaN     NaN  34.0  98.0
# Vada     F          NaN     NaN  23.0    NaN     NaN    86.0   NaN   NaN
# ...

# %%
company=pd.read_csv('fortune501.csv')
company
# Out:
#      Rank                               Title  Employees  \
# 0       1                             Walmart    2300000
# 1       2                  Berkshire Hathaway     367700
# 2       3                               Apple     116000
# 3       4                         Exxon Mobil      72700
# 4       5                            McKesson      68000
# 5       6                  UnitedHealth Group     230000
# 6       7                          CVS Health     204000
# 7       8                      General Motors     225000
# 8       9                                AT&T     268540
# 9      10                          Ford Motor     201000
# 10     11                   AmerisourceBergen      18500
# 11     12                          Amazon.com     341400
# 12     13                    General Electric     295000
# 13     14                             Verizon     160900
# 14     15                     Cardinal Health      37300
# ...

# %%
company.shape
# Out:
# (500, 8)

# %%
company.columns
# Out:
# Index(['Rank', 'Title', 'Employees', 'Sector', 'Industry', 'Hqlocation',
#        'Revenues', 'Profits'],
#       dtype='object')

# %%
company.head()
# Out:
#    Rank               Title  Employees       Sector  \
# 0     1             Walmart    2300000    Retailing
# 1     2  Berkshire Hathaway     367700   Financials
# 2     3               Apple     116000   Technology
# 3     4         Exxon Mobil      72700       Energy
# 4     5            McKesson      68000  Wholesalers
#
#                                    Industry         Hqlocation  Revenues  \
# 0                     General Merchandisers    Bentonville, AR    485873
# 1  Insurance: Property and Casualty (Stock)          Omaha, NE    223604
# 2               Computers, Office Equipment      Cupertino, CA    215639
# 3                        Petroleum Refining         Irving, TX    205004
# 4                  Wholesalers: Health Care  San Francisco, CA    192487
#
#    Profits
# 0  13643.0
# 1  24074.0
# 2  45687.0
# 3   7840.0
# 4   2258.0

# %%
sector=company.groupby('Sector')

# %%
sector

# %%
sector.size()
# Out:
# Sector
# Aerospace & Defense              12
# Apparel                           5
# Business Services                20
# Chemicals                        14
# Energy                           57
# Engineering & Construction       13
# Financials                       84
# Food & Drug Stores                7
# Food, Beverages & Tobacco        24
# Health Care                      38
# Hotels, Restaurants & Leisure    10
# Household Products               12
# Industrials                      19
# Materials                        19
# Media                            11
# Motor Vehicles & Parts            9
# Retailing                        47
# Technology                       43
# Telecommunications               10
# Transportation                   17
# Wholesalers                      29
# dtype: int64

# %%
sector.size().sort_values(ascending=False).head(1).index[0] #finding out the name of the sector with highest value
# Out:
# 'Financials'

# %%
sector.first()
# Out:
#                                Rank                     Title  Employees  \
# Sector
# Aerospace & Defense              24                    Boeing     150540
# Apparel                          88                      Nike      70700
# Business Services               146             ManpowerGroup      28000
# Chemicals                        62              Dow Chemical      56000
# Energy                            4               Exxon Mobil      72700
# Engineering & Construction      149                     Fluor      61551
# Financials                        2        Berkshire Hathaway     367700
# Food & Drug Stores               17  Walgreens Boots Alliance     300000
# Food, Beverages & Tobacco        44                   PepsiCo     264000
# Health Care                       6        UnitedHealth Group     230000
# Hotels, Restaurants & Leisure   112                McDonald’s     375000
# Household Products               36          Procter & Gamble     105000
# ...

# %%
sector.last()
# Out:
#                                Rank                               Title  \
# Sector
# Aerospace & Defense             492                    Rockwell Collins
# Apparel                         432                         Hanesbrands
# Business Services               500                      ABM Industries
# Chemicals                       484                            Celanese
# Energy                          499                       Vistra Energy
# Engineering & Construction      497                       Toll Brothers
# Financials                      483  Western & Southern Financial Group
# Food & Drug Stores              176                  Whole Foods Market
# Food, Beverages & Tobacco       486                            Seaboard
# Health Care                     454                  Genesis Healthcare
# Hotels, Restaurants & Leisure   461                   Wyndham Worldwide
# Household Products              474                              Mattel
# ...

# %%
sector.groups
# Out:
# {'Aerospace & Defense': Int64Index([23, 49, 55, 89, 113, 115, 199, 227, 272, 379, 392, 491], dtype='int64'),
#  'Apparel': Int64Index([87, 229, 334, 370, 431], dtype='int64'),
#  'Business Services': Int64Index([145, 178, 186, 191, 200, 239, 241, 263, 266, 298, 300, 344, 377,
#              451, 458, 470, 477, 489, 492, 499],
#             dtype='int64'),
#  'Chemicals': Int64Index([61, 112, 182, 203, 210, 235, 274, 288, 293, 308, 376, 466, 481,
#              483],
#             dtype='int64'),
#  'Energy': Int64Index([  3,  18,  33,  36,  50,  78,  88, 102, 114, 116, 120, 121, 140,
#              144, 156, 166, 169, 171, 172, 174, 193, 195, 214, 228, 230, 233,
#              234, 236, 237, 255, 262, 271, 273, 277, 279, 284, 307, 311, 327,
#              342, 343, 348, 355, 357, 361, 364, 366, 367, 374, 399, 401, 418,
#              430, 456, 479, 487, 498],
#             dtype='int64'),
# ...

# %%
sector.get_group('Apparel')
# Out:
#      Rank         Title  Employees Industry         Hqlocation  Revenues  \
# 87     88          Nike      70700  Apparel      Beaverton, OR     32376
# 229   230            VF      69000  Apparel     Greensboro, NC     12207
# 334   335           PVH      26650  Apparel       New York, NY      8203
# 370   371  Ralph Lauren      20500  Apparel       New York, NY      7405
# 431   432   Hanesbrands      67800  Apparel  Winston-Salem, NC      6063
#
#      Profits
# 87    3760.0
# 229   1074.1
# 334    549.0
# 370    396.0
# 431    539.4

# %%
sector.sum()
# Out:
#                                 Rank  Employees  Revenues   Profits
# Sector
# Aerospace & Defense             2416     863840    338302   25119.7
# Apparel                         1456     254650     66254    6318.5
# Business Services               6584     845050    194685   23107.1
# Chemicals                       3986     364906    188667   15918.3
# Energy                         14217     869511   1176417     370.6
# Engineering & Construction      4305     329090    124682    5072.2
# Financials                     20815    3161998   2067607  228461.2
# Food & Drug Stores               594    1390095    389686    8522.0
# Food, Beverages & Tobacco       5698    1000309    472806   56308.4
# Health Care                     6952    2341423   1318389  105383.9
# Hotels, Restaurants & Leisure   2860    1838742    121189   14510.6
# Household Products              3556     483344    180846   19803.7
# Industrials                     4506    1224296    418359   32826.1
# ...

# %%
sector.sum()['Revenues'].sort_values().tail(1)
# Out:
# Sector
# Financials    2067607
# Name: Revenues, dtype: int64

# %%
sector.mean()['Profits'].sort_values().tail(1)
# Out:
# Sector
# Technology    4137.24186
# Name: Profits, dtype: float64
